# %%
import random
import numpy as np
import pandas as pd
import dqn
import drqn
import dqn_markov


random.seed(42)
TEST_RATIO = 0.8
# ── paths ─────────────────────────────────────────────────────────────
CSV_A = '../dataset/CORN_USD_2005_2020.csv'   # ← change to your file
CSV_B = '../dataset/WHEAT_USD_2005_2020.csv'   # ← change to your file
CSV_C = '../data-scripts/data.csv'
CSV_D = '../data-scripts/data_one_regime.csv'
# ─────────────────────────────────────────────────────────────────────
df_as = []
df_bs = []
df_a_1 = pd.read_csv(CSV_A).dropna()
df_b_1 = pd.read_csv(CSV_B).dropna()
df_a_2 = pd.read_csv(CSV_C)[['s1']].dropna()
df_b_2 = pd.read_csv(CSV_C)[['s2']].dropna()
df_a_2 = df_a_2.rename(columns={"s1": "close"})
df_b_2 = df_b_2.rename(columns={"s2": "close"})
df_a_3 = pd.read_csv(CSV_D)[['s1']].dropna()
df_b_3 = pd.read_csv(CSV_D)[['s2']].dropna()
df_a_3 = df_a_3.rename(columns={"s1": "close"})
df_b_3 = df_b_3.rename(columns={"s2": "close"})

df_as = [df_a_1, df_a_2, df_a_3]
df_bs = [df_b_1, df_b_2, df_a_3]
for i in range(len(df_as)):
    df_as[i]=df_as[i][:int(TEST_RATIO*len(df_as[i]))]
    df_bs[i]=df_bs[i][:int(TEST_RATIO*len(df_bs[i]))]

agents = [dqn_markov, dqn, drqn]

# %%
iters = 5
arrs = np.zeros((3, 3, iters))
for j in range(len(agents)):
    for i in range(len(df_as)):
        for it in range(iters):
            ag, ret = agents[j].dqn(df_as[i], df_bs[i], random.randint(0, 10000000))
            arrs[j][i][it]=ret
# Out:
# Episode   10/100  return=  +2.602  avg10=  +0.666  ε=0.817  mem=6000
# Episode   20/100  return=  -0.393  avg10=  +1.273  ε=0.668  mem=15000
# Episode   30/100  return=  -0.030  avg10=  +0.509  ε=0.545  mem=19974
# Episode   40/100  return=  -0.363  avg10=  +1.492  ε=0.446  mem=26058
# Episode   50/100  return=  +0.677  avg10=  +0.734  ε=0.364  mem=33952
# Episode   60/100  return=  +0.563  avg10=  +3.261  ε=0.298  mem=40952
# Episode   70/100  return=  -0.986  avg10=  +1.374  ε=0.243  mem=47952
# Episode   80/100  return=  +2.028  avg10=  +2.199  ε=0.199  mem=50000
# Episode   90/100  return=  +9.013  avg10=  +3.740  ε=0.162  mem=50000
# Episode  100/100  return=  +0.919  avg10=  +1.328  ε=0.133  mem=50000
# Training complete.
# Test  total P&L : +1208.9223
# Test  final value: 1308.9223
# Test  realized PnL: +1208.9223
# Test  non-hold steps: 130218
# Episode   10/100  return=  +1.274  avg10=  +0.535  ε=0.817  mem=3000
# Episode   20/100  return=  +1.548  avg10=  -0.464  ε=0.668  mem=10000
# Episode   30/100  return=  +1.662  avg10=  +1.144  ε=0.545  mem=13827
# Episode   40/100  return=  +2.186  avg10=  +1.728  ε=0.446  mem=17827
# Episode   50/100  return=  +4.699  avg10=  +3.250  ε=0.364  mem=21989
# Episode   60/100  return=  +3.291  avg10=  +0.835  ε=0.298  mem=23283
# Episode   70/100  return=  +1.711  avg10=  +1.543  ε=0.243  mem=25084
# Episode   80/100  return=  +2.206  avg10=  +0.665  ε=0.199  mem=29084
# Episode   90/100  return=  +1.658  avg10=  +1.909  ε=0.162  mem=30675
# Episode  100/100  return=  -0.679  avg10=  +2.257  ε=0.133  mem=30675
# Training complete.
# Test  total P&L : +1325.1952
# Test  final value: 1425.1952
# Test  realized PnL: +1325.1952
# Test  non-hold steps: 165027
# Episode   10/100  return=  +0.322  avg10=  +0.489  ε=0.817  mem=4000
# Episode   20/100  return=  +1.183  avg10=  +1.307  ε=0.668  mem=6000
# Episode   30/100  return=  +1.479  avg10=  +1.799  ε=0.545  mem=9000
# Episode   40/100  return=  +1.716  avg10=  +1.693  ε=0.446  mem=11000
# Episode   50/100  return=  -0.494  avg10=  +0.376  ε=0.364  mem=14000
# Episode   60/100  return=  +0.100  avg10=  +1.700  ε=0.298  mem=17821
# Episode   70/100  return=  +4.824  avg10=  +0.583  ε=0.243  mem=18821
# Episode   80/100  return=  -0.251  avg10=  +1.686  ε=0.199  mem=21019
# Episode   90/100  return=  +0.246  avg10=  +1.055  ε=0.162  mem=25019
# Episode  100/100  return=  +1.480  avg10=  +1.220  ε=0.133  mem=28297
# Training complete.
# Test  total P&L : +612.4982
# Test  final value: 712.4982
# Test  realized PnL: +612.4982
# Test  non-hold steps: 48849
# Episode   10/100  return=  -0.314  avg10=  +0.436  ε=0.817  mem=7000
# Episode   20/100  return=  +0.552  avg10=  +0.013  ε=0.668  mem=13370
# Episode   30/100  return=  +1.840  avg10=  +1.149  ε=0.545  mem=20448
# Episode   40/100  return=  +1.720  avg10=  +1.592  ε=0.446  mem=29448
# Episode   50/100  return=  -0.073  avg10=  +2.205  ε=0.364  mem=34402
# Episode   60/100  return=  -2.959  avg10=  +1.968  ε=0.298  mem=41402
# Episode   70/100  return=  +7.578  avg10=  +3.554  ε=0.243  mem=48402
# Episode   80/100  return=  +5.021  avg10=  +3.354  ε=0.199  mem=50000
# Episode   90/100  return=  +3.095  avg10=  +3.128  ε=0.162  mem=50000
# Episode  100/100  return=  +1.807  avg10=  +1.495  ε=0.133  mem=50000
# Training complete.
# Test  total P&L : +3227.5318
# Test  final value: 3327.5318
# Test  realized PnL: +3227.5318
# Test  non-hold steps: 144690
# Episode   10/100  return=  -1.838  avg10=  +1.621  ε=0.817  mem=5955
# Episode   20/100  return=  +0.322  avg10=  +0.253  ε=0.668  mem=12533
# Episode   30/100  return=  +5.295  avg10=  +0.441  ε=0.545  mem=19533
# Episode   40/100  return=  +1.230  avg10=  +2.100  ε=0.446  mem=24181
# Episode   50/100  return=  +7.495  avg10=  +2.442  ε=0.364  mem=32181
# Episode   60/100  return=  +7.558  avg10=  +2.566  ε=0.298  mem=41278
# Episode   70/100  return=  +5.234  avg10=  +1.635  ε=0.243  mem=49767
# Episode   80/100  return=  +2.354  avg10=  +2.142  ε=0.199  mem=50000
# Episode   90/100  return=  +1.209  avg10=  +2.212  ε=0.162  mem=50000
# Episode  100/100  return=  +8.388  avg10=  +3.240  ε=0.133  mem=50000
# Training complete.
# Test  total P&L : +962.7765
# Test  final value: 1062.7765
# Test  realized PnL: +962.7765
# Test  non-hold steps: 158914
# Episode   10/100  return=  -4.295  avg10=-1058.588  ε=0.817  mem=3873
# Episode   20/100  return=  -2.913  avg10=  -0.575  ε=0.668  mem=3873
# Episode   30/100  return= +13.751  avg10=  +1.699  ε=0.545  mem=7873
# Episode   40/100  return= +22.551  avg10= -31.314  ε=0.446  mem=11887
# Episode   50/100  return= -58.481  avg10=  -8.697  ε=0.364  mem=15913
# Episode   60/100  return=  +6.653  avg10=  -3.589  ε=0.298  mem=17085
# Episode   70/100  return=  +8.010  avg10=  +0.812  ε=0.243  mem=18760
# Episode   80/100  return= +28.267  avg10=  -1.203  ε=0.199  mem=20760
# Episode   90/100  return=  +4.192  avg10=+1117.290  ε=0.162  mem=23760
# Episode  100/100  return=+21732.821  avg10=+2157.079  ε=0.133  mem=27271
# Training complete.
# Test  total P&L : +242.5644
# Test  final value: 342.5644
# Test  realized PnL: +242.5644
# Test  non-hold steps: 51200
# Episode   10/100  return=  +1.744  avg10=-16986.444  ε=0.817  mem=8000
# Episode   20/100  return= +10.848  avg10=  +9.156  ε=0.668  mem=16920
# Episode   30/100  return=  +9.790  avg10=  +7.386  ε=0.545  mem=23258
# Episode   40/100  return=  +3.399  avg10=  +0.405  ε=0.446  mem=32930
# Episode   50/100  return= -32.065  avg10= -79.525  ε=0.364  mem=41930
# Episode   60/100  return=  +2.354  avg10= -19.670  ε=0.298  mem=47930
# Episode   70/100  return=  +9.265  avg10=  -1.482  ε=0.243  mem=50000
# Episode   80/100  return=  -1.792  avg10=+529467.147  ε=0.199  mem=50000
# Episode   90/100  return=  -2.962  avg10=  +1.384  ε=0.162  mem=50000
# Episode  100/100  return= +10.541  avg10=  +7.658  ε=0.133  mem=50000
# Training complete.
# Test  total P&L : -115.4131
# Test  final value: -15.4131
# Test  realized PnL: -115.4131
# Test  non-hold steps: 17789
# Episode   10/100  return=  -1.019  avg10= -10.164  ε=0.817  mem=6000
# Episode   20/100  return= +11.157  avg10= -13.581  ε=0.668  mem=14000
# Episode   30/100  return=  +3.542  avg10= -78.133  ε=0.545  mem=22818
# Episode   40/100  return=  +6.927  avg10=  +0.256  ε=0.446  mem=28363
# Episode   50/100  return=  +3.542  avg10= -22.558  ε=0.364  mem=37363
# Episode   60/100  return= +16.949  avg10= +16.561  ε=0.298  mem=46377
# Episode   70/100  return=  -2.854  avg10=  +4.512  ε=0.243  mem=50000
# Episode   80/100  return=  +0.060  avg10=+110.325  ε=0.199  mem=50000
# Episode   90/100  return=  -0.189  avg10=  +4.780  ε=0.162  mem=50000
# Episode  100/100  return=  +0.389  avg10=+213.273  ε=0.133  mem=50000
# Training complete.
# Test  total P&L : +110.1798
# Test  final value: 210.1798
# Test  realized PnL: +110.1798
# Test  non-hold steps: 13916
# Episode   10/100  return=  +8.943  avg10=  +7.727  ε=0.817  mem=7774
# Episode   20/100  return=  +8.371  avg10= -34.944  ε=0.668  mem=13305
# Episode   30/100  return= +30.892  avg10=  +2.159  ε=0.545  mem=18345
# Episode   40/100  return=  +5.883  avg10=  -2.306  ε=0.446  mem=24345
# Episode   50/100  return= -23.818  avg10= -10.468  ε=0.364  mem=31573
# Episode   60/100  return=  +1.207  avg10=+2179.616  ε=0.298  mem=38573
# Episode   70/100  return=  +4.411  avg10=  +0.668  ε=0.243  mem=45573
# Episode   80/100  return=  +3.881  avg10=  +2.878  ε=0.199  mem=50000
# Episode   90/100  return=  +6.178  avg10=  -0.413  ε=0.162  mem=50000
# Episode  100/100  return=  -9.234  avg10=-132.623  ε=0.133  mem=50000
# Training complete.
# Test  total P&L : +115.4131
# Test  final value: 215.4131
# Test  realized PnL: +115.4131
# Test  non-hold steps: 17684
# Episode   10/100  return=  +0.799  avg10=+667.654  ε=0.817  mem=1000
# Episode   20/100  return=  +0.711  avg10= +23.270  ε=0.668  mem=6000
# Episode   30/100  return=  -6.550  avg10=-3725574.140  ε=0.545  mem=10000
# Episode   40/100  return=  +7.826  avg10=-530.614  ε=0.446  mem=14000
# Episode   50/100  return=  -3.383  avg10= -16.912  ε=0.364  mem=16000
# Episode   60/100  return=  +4.474  avg10= -26.535  ε=0.298  mem=19012
# Episode   70/100  return=  -7.669  avg10=  -9.174  ε=0.243  mem=20012
# Episode   80/100  return=  -3.867  avg10=  -0.518  ε=0.199  mem=23012
# Episode   90/100  return=  +1.794  avg10=  -2.763  ε=0.162  mem=26463
# Episode  100/100  return=  -2.336  avg10=  -5.490  ε=0.133  mem=27463
# Training complete.
# Test  total P&L : +61.2494
# Test  final value: 161.2494
# Test  realized PnL: +61.2494
# Test  non-hold steps: 51200
# Episode   10/100  return=  +0.000  avg10=  -0.000  ε=0.817  mem=10000
# Episode   20/100  return=  +0.000  avg10=  -0.000  ε=0.668  mem=20000
# Episode   30/100  return=  +0.000  avg10=  -0.000  ε=0.545  mem=30000
# Episode   40/100  return=  +0.000  avg10=  +0.000  ε=0.446  mem=40000
# Episode   50/100  return=  +0.000  avg10=  -0.000  ε=0.364  mem=50000
# Episode   60/100  return=  +0.000  avg10=  +0.000  ε=0.298  mem=50000
# Episode   70/100  return=  +0.000  avg10=  +0.000  ε=0.243  mem=50000
# Episode   80/100  return=  +0.000  avg10=  -0.000  ε=0.199  mem=50000
# Episode   90/100  return=  -0.000  avg10=  +0.000  ε=0.162  mem=50000
# Episode  100/100  return=  +0.000  avg10=  +0.000  ε=0.133  mem=50000
# Training complete.
# Test  total P&L : +0.0000
# Test  final value: 100.0000
# Test  realized PnL: +0.0000
# Test  non-hold steps: 48000
# Episode   10/100  return=  +0.000  avg10=  -0.000  ε=0.817  mem=0
# Episode   20/100  return=  +0.000  avg10=  +0.000  ε=0.668  mem=0
# Episode   30/100  return=  +0.000  avg10=  +0.000  ε=0.545  mem=0
# Episode   40/100  return=  +0.000  avg10=  +0.000  ε=0.446  mem=0
# Episode   50/100  return=  +0.000  avg10=  +0.000  ε=0.364  mem=0
# Episode   60/100  return=  +0.000  avg10=  +0.000  ε=0.298  mem=0
# Episode   70/100  return=  +0.000  avg10=  -0.000  ε=0.243  mem=0
# Episode   80/100  return=  +0.000  avg10=  +0.000  ε=0.199  mem=0
# Episode   90/100  return=  +0.000  avg10=  +0.000  ε=0.162  mem=0
# Episode  100/100  return=  +0.000  avg10=  +0.000  ε=0.133  mem=0
# Training complete.
# Test  total P&L : +0.0000
# Test  final value: 100.0000
# Test  realized PnL: -0.0000
# Test  non-hold steps: 2
# Episode   10/100  return=  +0.000  avg10=  +0.000  ε=0.817  mem=10000
# Episode   20/100  return=  +0.000  avg10=  +0.000  ε=0.668  mem=20000
# Episode   30/100  return=  +0.000  avg10=  -0.000  ε=0.545  mem=30000
# Episode   40/100  return=  +0.000  avg10=  +0.000  ε=0.446  mem=40000
# Episode   50/100  return=  +0.000  avg10=  +0.000  ε=0.364  mem=50000
# Episode   60/100  return=  +0.000  avg10=  +0.000  ε=0.298  mem=50000
# Episode   70/100  return=  +0.000  avg10=  +0.000  ε=0.243  mem=50000
# Episode   80/100  return=  -0.000  avg10=  +0.000  ε=0.199  mem=50000
# Episode   90/100  return=  +0.000  avg10=  +0.000  ε=0.162  mem=50000
# Episode  100/100  return=  +0.000  avg10=  +0.000  ε=0.133  mem=50000
# Training complete.
# Test  total P&L : +0.0000
# Test  final value: 100.0000
# Test  realized PnL: +0.0000
# Test  non-hold steps: 48000
# Episode   10/100  return=  +0.000  avg10=  -0.000  ε=0.817  mem=10000
# Episode   20/100  return=  +0.000  avg10=  +0.000  ε=0.668  mem=20000
# Episode   30/100  return=  +0.000  avg10=  -0.000  ε=0.545  mem=30000
# Episode   40/100  return=  +0.000  avg10=  -0.000  ε=0.446  mem=40000
# Episode   50/100  return=  +0.000  avg10=  +0.000  ε=0.364  mem=50000
# Episode   60/100  return=  +0.000  avg10=  +0.000  ε=0.298  mem=50000
# Episode   70/100  return=  +0.000  avg10=  -0.000  ε=0.243  mem=50000
# Episode   80/100  return=  +0.000  avg10=  +0.000  ε=0.199  mem=50000
# Episode   90/100  return=  +0.000  avg10=  -0.000  ε=0.162  mem=50000
# Episode  100/100  return=  +0.000  avg10=  +0.000  ε=0.133  mem=50000
# Training complete.
# Test  total P&L : +0.0000
# Test  final value: 100.0000
# Test  realized PnL: -0.0000
# Test  non-hold steps: 48000
# Episode   10/100  return=  +0.000  avg10=  +0.000  ε=0.817  mem=10000
# Episode   20/100  return=  +0.000  avg10=  +0.000  ε=0.668  mem=20000
# Episode   30/100  return=  +0.000  avg10=  +0.000  ε=0.545  mem=30000
# Episode   40/100  return=  +0.000  avg10=  +0.000  ε=0.446  mem=40000
# Episode   50/100  return=  +0.000  avg10=  -0.000  ε=0.364  mem=50000
# Episode   60/100  return=  +0.000  avg10=  +0.000  ε=0.298  mem=50000
# Episode   70/100  return=  +0.000  avg10=  +0.000  ε=0.243  mem=50000
# Episode   80/100  return=  +0.000  avg10=  +0.000  ε=0.199  mem=50000
# Episode   90/100  return=  +0.000  avg10=  +0.000  ε=0.162  mem=50000
# Episode  100/100  return=  +0.000  avg10=  -0.000  ε=0.133  mem=50000
# Training complete.
# Test  total P&L : +0.0000
# Test  final value: 100.0000
# Test  realized PnL: +0.0000
# Test  non-hold steps: 0
# Episode   10/100  return=  -1.726  avg10=  +0.092  ε=0.817  mem=10000
# Episode   20/100  return=  -0.237  avg10=  +0.896  ε=0.668  mem=20000
# Episode   30/100  return=  +0.667  avg10=  +0.231  ε=0.545  mem=30000
# Episode   40/100  return=  -0.186  avg10=  +0.226  ε=0.446  mem=40000
# Episode   50/100  return= +10.066  avg10=  +1.374  ε=0.364  mem=50000
# Episode   60/100  return=  +1.755  avg10=  +2.039  ε=0.298  mem=50000
# Episode   70/100  return=  +4.652  avg10=  +3.054  ε=0.243  mem=50000
# Episode   80/100  return=  +2.901  avg10=  +2.881  ε=0.199  mem=50000
# Episode   90/100  return=  +2.846  avg10=  +3.075  ε=0.162  mem=50000
# Episode  100/100  return=  -1.035  avg10=  +1.584  ε=0.133  mem=50000
# Training complete.
# Test  total P&L : +558.3459
# Test  final value: 658.3459
# Test  realized PnL: +558.3459
# Test  non-hold steps: 79860
# Episode   10/100  return=  +0.119  avg10=  +0.171  ε=0.817  mem=10000
# Episode   20/100  return=  +2.827  avg10=  -0.934  ε=0.668  mem=20000
# Episode   30/100  return=  -0.503  avg10=  +1.548  ε=0.545  mem=30000
# Episode   40/100  return=  +2.939  avg10=  +1.482  ε=0.446  mem=40000
# Episode   50/100  return=  +5.860  avg10=  +0.468  ε=0.364  mem=50000
# Episode   60/100  return=  +0.766  avg10=  +1.535  ε=0.298  mem=50000
# Episode   70/100  return=  +1.981  avg10=  +1.346  ε=0.243  mem=50000
# Episode   80/100  return=  -0.013  avg10=  +2.609  ε=0.199  mem=50000
# Episode   90/100  return=  +1.215  avg10=  +1.493  ε=0.162  mem=50000
# Episode  100/100  return=  +2.299  avg10=  +3.547  ε=0.133  mem=50000
# Training complete.
# Test  total P&L : +2855.2111
# Test  final value: 2955.2111
# Test  realized PnL: +2855.2111
# Test  non-hold steps: 114748
# Episode   10/100  return=  +1.567  avg10=  +0.287  ε=0.817  mem=10000
# Episode   20/100  return=  -1.837  avg10=  -0.086  ε=0.668  mem=20000
# Episode   30/100  return=  +8.761  avg10=  +2.390  ε=0.545  mem=30000
# Episode   40/100  return=  -1.130  avg10=  +0.824  ε=0.446  mem=40000
# Episode   50/100  return=  +2.778  avg10=  +1.725  ε=0.364  mem=50000
# Episode   60/100  return=  +3.835  avg10=  +3.605  ε=0.298  mem=50000
# Episode   70/100  return=  +0.729  avg10=  +1.355  ε=0.243  mem=50000
# Episode   80/100  return=  +1.372  avg10=  +3.074  ε=0.199  mem=50000
# Episode   90/100  return=  +0.424  avg10=  +1.997  ε=0.162  mem=50000
# Episode  100/100  return=  -1.012  avg10=  +2.877  ε=0.133  mem=50000
# Training complete.
# Test  total P&L : +1659.9388
# Test  final value: 1759.9388
# Test  realized PnL: +1659.9388
# Test  non-hold steps: 169900
# Episode   10/100  return=  -0.498  avg10=  +0.825  ε=0.817  mem=10000
# Episode   20/100  return=  +2.481  avg10=  +0.914  ε=0.668  mem=20000
# Episode   30/100  return=  +1.018  avg10=  +2.439  ε=0.545  mem=30000
# Episode   40/100  return=  +0.036  avg10=  +0.151  ε=0.446  mem=40000
# Episode   50/100  return=  +2.508  avg10=  +0.676  ε=0.364  mem=50000
# Episode   60/100  return=  +0.926  avg10=  +1.424  ε=0.298  mem=50000
# Episode   70/100  return=  +0.712  avg10=  +2.026  ε=0.243  mem=50000
# Episode   80/100  return=  +2.873  avg10=  +2.789  ε=0.199  mem=50000
# Episode   90/100  return=  +4.156  avg10=  +2.363  ε=0.162  mem=50000
# Episode  100/100  return=  +5.159  avg10=  +3.988  ε=0.133  mem=50000
# Training complete.
# Test  total P&L : +538.3593
# Test  final value: 638.3593
# Test  realized PnL: +538.3593
# Test  non-hold steps: 35594
# Episode   10/100  return=  -1.258  avg10=  +0.692  ε=0.817  mem=10000
# Episode   20/100  return=  +0.912  avg10=  +1.106  ε=0.668  mem=20000
# Episode   30/100  return=  +1.695  avg10=  +1.078  ε=0.545  mem=30000
# Episode   40/100  return=  -0.307  avg10=  +1.563  ε=0.446  mem=40000
# Episode   50/100  return=  +2.582  avg10=  +1.183  ε=0.364  mem=50000
# Episode   60/100  return=  +0.121  avg10=  +1.131  ε=0.298  mem=50000
# Episode   70/100  return=  +3.711  avg10=  +1.822  ε=0.243  mem=50000
# Episode   80/100  return=  +2.717  avg10=  +1.809  ε=0.199  mem=50000
# Episode   90/100  return=  +6.708  avg10=  +1.942  ε=0.162  mem=50000
# Episode  100/100  return=  -3.484  avg10=  +1.566  ε=0.133  mem=50000
# Training complete.
# Test  total P&L : +2157.5146
# Test  final value: 2257.5146
# Test  realized PnL: +2157.5146
# Test  non-hold steps: 167610
# Episode   10/100  return=  +1.316  avg10=  -4.789  ε=0.817  mem=10000
# Episode   20/100  return=-103.674  avg10= -32.262  ε=0.668  mem=20000
# Episode   30/100  return= +22.354  avg10=  +2.396  ε=0.545  mem=30000
# Episode   40/100  return=  +2.192  avg10=  -0.986  ε=0.446  mem=40000
# Episode   50/100  return=  +1.007  avg10=  +0.902  ε=0.364  mem=50000
# Episode   60/100  return= -53.616  avg10=  -6.212  ε=0.298  mem=50000
# Episode   70/100  return= +19.510  avg10= -11.246  ε=0.243  mem=50000
# Episode   80/100  return=  +1.960  avg10=-1118.406  ε=0.199  mem=50000
# Episode   90/100  return=  +8.979  avg10=  -3.916  ε=0.162  mem=50000
# Episode  100/100  return=-103.835  avg10= -14.517  ε=0.133  mem=50000
# Training complete.
# Test  total P&L : +274.3826
# Test  final value: 374.3826
# Test  realized PnL: +274.3826
# Test  non-hold steps: 51200
# Episode   10/100  return=  +0.177  avg10=  -7.336  ε=0.817  mem=10000
# Episode   20/100  return= -15.466  avg10=  -1.336  ε=0.668  mem=20000
# Episode   30/100  return=  +7.654  avg10=  -8.776  ε=0.545  mem=30000
# Episode   40/100  return=  +3.734  avg10=  -3.835  ε=0.446  mem=40000
# Episode   50/100  return= +30.661  avg10=+378.282  ε=0.364  mem=50000
# Episode   60/100  return= -42.255  avg10= -34.613  ε=0.298  mem=50000
# Episode   70/100  return= -12.644  avg10=-15502.852  ε=0.243  mem=50000
# Episode   80/100  return=  +0.261  avg10= -35.261  ε=0.199  mem=50000
# Episode   90/100  return=  +4.143  avg10=  +5.186  ε=0.162  mem=50000
# Episode  100/100  return=  +8.582  avg10= +26.475  ε=0.133  mem=50000
# Training complete.
# Test  total P&L : +568.7445
# Test  final value: 668.7445
# Test  realized PnL: +568.7445
# Test  non-hold steps: 51200
# Episode   10/100  return=  +9.234  avg10=-1727257.728  ε=0.817  mem=10000
# Episode   20/100  return= +21.792  avg10=  +5.019  ε=0.668  mem=20000
# Episode   30/100  return=  +5.632  avg10= +12.917  ε=0.545  mem=30000
# Episode   40/100  return=  +0.272  avg10= -20.335  ε=0.446  mem=40000
# Episode   50/100  return=  -9.134  avg10=-261187.289  ε=0.364  mem=50000
# Episode   60/100  return=  +2.987  avg10= +22.149  ε=0.298  mem=50000
# Episode   70/100  return=  +9.187  avg10= -11.103  ε=0.243  mem=50000
# Episode   80/100  return=  -4.261  avg10=  -4.863  ε=0.199  mem=50000
# Episode   90/100  return=  -2.022  avg10= -25.812  ε=0.162  mem=50000
# Episode  100/100  return=  +8.088  avg10=-11579.856  ε=0.133  mem=50000
# Training complete.
# Test  total P&L : +274.3826
# Test  final value: 374.3826
# Test  realized PnL: +274.3826
# Test  non-hold steps: 51200
# Episode   10/100  return= -99.762  avg10=  -7.423  ε=0.817  mem=10000
# Episode   20/100  return= -34.973  avg10=  -9.534  ε=0.668  mem=20000
# Episode   30/100  return=  -4.213  avg10=+54995.605  ε=0.545  mem=30000
# Episode   40/100  return=  +3.405  avg10= +10.310  ε=0.446  mem=40000
# Episode   50/100  return=  +4.115  avg10=  -0.222  ε=0.364  mem=50000
# Episode   60/100  return=  +7.868  avg10= +10.838  ε=0.298  mem=50000
# Episode   70/100  return= -12.185  avg10= -22.108  ε=0.243  mem=50000
# Episode   80/100  return=  +8.119  avg10= -10.392  ε=0.199  mem=50000
# Episode   90/100  return=  +7.478  avg10=  -7.679  ε=0.162  mem=50000
# Episode  100/100  return= -27.208  avg10= -17.330  ε=0.133  mem=50000
# Training complete.
# Test  total P&L : +274.3826
# Test  final value: 374.3826
# Test  realized PnL: +274.3826
# Test  non-hold steps: 51200
# Episode   10/100  return=  -2.250  avg10= -10.497  ε=0.817  mem=10000
# Episode   20/100  return=  -1.612  avg10=  +0.486  ε=0.668  mem=20000
# Episode   30/100  return= -35.503  avg10=-5517.943  ε=0.545  mem=30000
# Episode   40/100  return=  -1.567  avg10=-132.760  ε=0.446  mem=40000
# Episode   50/100  return= +10.140  avg10=  +8.827  ε=0.364  mem=50000
# Episode   60/100  return=  +3.082  avg10=  +0.979  ε=0.298  mem=50000
# Episode   70/100  return=  -6.271  avg10=  -2.004  ε=0.243  mem=50000
# Episode   80/100  return=  -0.188  avg10=  +1.506  ε=0.199  mem=50000
# Episode   90/100  return=  -1.860  avg10=  -0.630  ε=0.162  mem=50000
# Episode  100/100  return= -17.644  avg10=+70094.378  ε=0.133  mem=50000
# Training complete.
# Test  total P&L : +0.0000
# Test  final value: 100.0000
# Test  realized PnL: +0.0000
# Test  non-hold steps: 0
# Episode   10/100  return=  +0.000  avg10=  +0.000  ε=0.817  mem=10000
# Episode   20/100  return=  +0.000  avg10=  +0.000  ε=0.668  mem=20000
# Episode   30/100  return=  +0.000  avg10=  +0.000  ε=0.545  mem=30000
# Episode   40/100  return=  +0.000  avg10=  +0.000  ε=0.446  mem=40000
# Episode   50/100  return=  +0.000  avg10=  +0.000  ε=0.364  mem=50000
# Episode   60/100  return=  +0.000  avg10=  +0.000  ε=0.298  mem=50000
# Episode   70/100  return=  +0.000  avg10=  -0.000  ε=0.243  mem=50000
# Episode   80/100  return=  +0.000  avg10=  -0.000  ε=0.199  mem=50000
# Episode   90/100  return=  +0.000  avg10=  +0.000  ε=0.162  mem=50000
# Episode  100/100  return=  +0.000  avg10=  +0.000  ε=0.133  mem=50000
# Training complete.
# Test  total P&L : +0.0000
# Test  final value: 100.0000
# Test  realized PnL: -0.0000
# Test  non-hold steps: 48000
# Episode   10/100  return=  +0.000  avg10=  +0.000  ε=0.817  mem=10000
# Episode   20/100  return=  -0.000  avg10=  -0.000  ε=0.668  mem=20000
# Episode   30/100  return=  +0.000  avg10=  -0.000  ε=0.545  mem=30000
# Episode   40/100  return=  +0.000  avg10=  +0.000  ε=0.446  mem=40000
# Episode   50/100  return=  +0.000  avg10=  +0.000  ε=0.364  mem=50000
# Episode   60/100  return=  +0.000  avg10=  -0.000  ε=0.298  mem=50000
# Episode   70/100  return=  +0.000  avg10=  +0.000  ε=0.243  mem=50000
# Episode   80/100  return=  +0.000  avg10=  +0.000  ε=0.199  mem=50000
# Episode   90/100  return=  +0.000  avg10=  -0.000  ε=0.162  mem=50000
# Episode  100/100  return=  +0.000  avg10=  -0.000  ε=0.133  mem=50000
# Training complete.
# Test  total P&L : +0.0000
# Test  final value: 100.0000
# Test  realized PnL: +0.0000
# Test  non-hold steps: 48000
# Episode   10/100  return=  +0.000  avg10=  -0.000  ε=0.817  mem=10000
# Episode   20/100  return=  +0.000  avg10=  +0.000  ε=0.668  mem=20000
# Episode   30/100  return=  -0.000  avg10=  +0.000  ε=0.545  mem=30000
# Episode   40/100  return=  -0.000  avg10=  -0.000  ε=0.446  mem=40000
# Episode   50/100  return=  +0.000  avg10=  +0.000  ε=0.364  mem=50000
# Episode   60/100  return=  +0.000  avg10=  +0.000  ε=0.298  mem=50000
# Episode   70/100  return=  +0.000  avg10=  +0.000  ε=0.243  mem=50000
# Episode   80/100  return=  +0.000  avg10=  +0.000  ε=0.199  mem=50000
# Episode   90/100  return=  +0.000  avg10=  +0.000  ε=0.162  mem=50000
# Episode  100/100  return=  +0.000  avg10=  +0.000  ε=0.133  mem=50000
# Training complete.
# Test  total P&L : +0.0000
# Test  final value: 100.0000
# Test  realized PnL: +0.0000
# Test  non-hold steps: 0
# Episode   10/100  return=  +0.000  avg10=  +0.000  ε=0.817  mem=10000
# Episode   20/100  return=  +0.000  avg10=  -0.000  ε=0.668  mem=20000
# Episode   30/100  return=  +0.000  avg10=  +0.000  ε=0.545  mem=30000
# Episode   40/100  return=  +0.000  avg10=  +0.000  ε=0.446  mem=40000
# Episode   50/100  return=  +0.000  avg10=  +0.000  ε=0.364  mem=50000
# Episode   60/100  return=  +0.000  avg10=  +0.000  ε=0.298  mem=50000
# Episode   70/100  return=  +0.000  avg10=  +0.000  ε=0.243  mem=50000
# Episode   80/100  return=  +0.000  avg10=  -0.000  ε=0.199  mem=50000
# Episode   90/100  return=  +0.000  avg10=  -0.000  ε=0.162  mem=50000
# Episode  100/100  return=  -0.000  avg10=  +0.000  ε=0.133  mem=50000
# Training complete.
# Test  total P&L : +0.0000
# Test  final value: 100.0000
# Test  realized PnL: +0.0000
# Test  non-hold steps: 0
# Episode   10/100  return=  +0.000  avg10=  -0.000  ε=0.817  mem=10000
# Episode   20/100  return=  +0.000  avg10=  -0.000  ε=0.668  mem=20000
# Episode   30/100  return=  +0.000  avg10=  +0.000  ε=0.545  mem=30000
# Episode   40/100  return=  +0.000  avg10=  +0.000  ε=0.446  mem=40000
# Episode   50/100  return=  +0.000  avg10=  -0.000  ε=0.364  mem=50000
# Episode   60/100  return=  -0.000  avg10=  +0.000  ε=0.298  mem=50000
# Episode   70/100  return=  +0.000  avg10=  -0.000  ε=0.243  mem=50000
# Episode   80/100  return=  +0.000  avg10=  +0.000  ε=0.199  mem=50000
# Episode   90/100  return=  +0.000  avg10=  -0.000  ε=0.162  mem=50000
# Episode  100/100  return=  +0.000  avg10=  +0.000  ε=0.133  mem=50000
# Training complete.
# Test  total P&L : +0.0000
# Test  final value: 100.0000
# Test  realized PnL: +0.0000
# Test  non-hold steps: 48000
# Episode   10/100  return=  +1.520  avg10=  -1.093  ε=0.817  mem=10000
# Episode   20/100  return=  +1.241  avg10=  +1.408  ε=0.668  mem=20000
# Episode   30/100  return=  -0.250  avg10=  +0.716  ε=0.545  mem=30000
# Episode   40/100  return=  +2.509  avg10=  +0.811  ε=0.446  mem=40000
# Episode   50/100  return=  +1.143  avg10=  +1.306  ε=0.364  mem=50000
# Episode   60/100  return=  +1.095  avg10=  +1.070  ε=0.298  mem=50000
# Episode   70/100  return=  +8.599  avg10=  +2.367  ε=0.243  mem=50000
# Episode   80/100  return=  -0.283  avg10=  +1.451  ε=0.199  mem=50000
# Episode   90/100  return=  +3.239  avg10=  +2.565  ε=0.162  mem=50000
# Episode  100/100  return=  +0.435  avg10=  +2.009  ε=0.133  mem=50000
# Training complete.
# Test  total P&L : +150.7991
# Test  final value: 250.7991
# Test  realized PnL: +150.7991
# Test  non-hold steps: 7589
# Episode   10/100  return=  +0.034  avg10=  +0.481  ε=0.817  mem=10000
# Episode   20/100  return=  +1.897  avg10=  +0.521  ε=0.668  mem=20000
# Episode   30/100  return=  +0.270  avg10=  +1.511  ε=0.545  mem=30000
# Episode   40/100  return=  +0.749  avg10=  +1.428  ε=0.446  mem=40000
# Episode   50/100  return=  -0.396  avg10=  +1.741  ε=0.364  mem=50000
# Episode   60/100  return=  +0.496  avg10=  +2.342  ε=0.298  mem=50000
# Episode   70/100  return=  +1.514  avg10=  +2.064  ε=0.243  mem=50000
# Episode   80/100  return=  +1.396  avg10=  +0.771  ε=0.199  mem=50000
# Episode   90/100  return=  +1.016  avg10=  +2.101  ε=0.162  mem=50000
# Episode  100/100  return=  +1.175  avg10=  +0.979  ε=0.133  mem=50000
# Training complete.
# Test  total P&L : +378.9219
# Test  final value: 478.9219
# Test  realized PnL: +378.9219
# Test  non-hold steps: 49680
# Episode   10/100  return=  -0.139  avg10=  +0.880  ε=0.817  mem=10000
# Episode   20/100  return=  -0.368  avg10=  +0.613  ε=0.668  mem=20000
# Episode   30/100  return=  +1.087  avg10=  +1.206  ε=0.545  mem=30000
# Episode   40/100  return=  +0.015  avg10=  +0.414  ε=0.446  mem=40000
# Episode   50/100  return=  +2.018  avg10=  +0.985  ε=0.364  mem=50000
# Episode   60/100  return=  +3.266  avg10=  +1.827  ε=0.298  mem=50000
# Episode   70/100  return=  +4.090  avg10=  +3.142  ε=0.243  mem=50000
# Episode   80/100  return=  -1.025  avg10=  +3.683  ε=0.199  mem=50000
# Episode   90/100  return=  -1.374  avg10=  +3.295  ε=0.162  mem=50000
# Episode  100/100  return=  +7.757  avg10=  +2.391  ε=0.133  mem=50000
# Training complete.
# Test  total P&L : +2521.7738
# Test  final value: 2621.7738
# Test  realized PnL: +2521.7738
# Test  non-hold steps: 106701
# Episode   10/100  return=  +0.525  avg10=  -0.343  ε=0.817  mem=10000
# Episode   20/100  return=  -0.595  avg10=  -0.255  ε=0.668  mem=20000
# Episode   30/100  return=  +1.519  avg10=  +0.958  ε=0.545  mem=30000
# Episode   40/100  return=  -0.277  avg10=  +0.143  ε=0.446  mem=40000
# Episode   50/100  return=  +0.887  avg10=  +1.563  ε=0.364  mem=50000
# Episode   60/100  return=  +4.576  avg10=  +2.501  ε=0.298  mem=50000
# Episode   70/100  return=  +1.714  avg10=  +1.473  ε=0.243  mem=50000
# Episode   80/100  return=  +0.244  avg10=  +1.318  ε=0.199  mem=50000
# Episode   90/100  return=  +0.460  avg10=  +1.819  ε=0.162  mem=50000
# Episode  100/100  return=  +0.430  avg10=  +1.733  ε=0.133  mem=50000
# Training complete.
# Test  total P&L : +622.5891
# Test  final value: 722.5891
# Test  realized PnL: +622.5891
# Test  non-hold steps: 79271
# Episode   10/100  return=  -0.426  avg10=  +0.602  ε=0.817  mem=10000
# Episode   20/100  return=  +0.252  avg10=  +0.356  ε=0.668  mem=20000
# Episode   30/100  return=  +2.015  avg10=  +0.629  ε=0.545  mem=30000
# Episode   40/100  return=  +0.168  avg10=  +1.684  ε=0.446  mem=40000
# Episode   50/100  return=  +1.003  avg10=  +1.513  ε=0.364  mem=50000
# Episode   60/100  return=  +2.899  avg10=  +2.996  ε=0.298  mem=50000
# Episode   70/100  return=  +6.015  avg10=  +2.366  ε=0.243  mem=50000
# Episode   80/100  return=  +2.927  avg10=  +2.080  ε=0.199  mem=50000
# Episode   90/100  return=  +0.488  avg10=  +2.824  ε=0.162  mem=50000
# Episode  100/100  return=  -0.591  avg10=  +1.216  ε=0.133  mem=50000
# Training complete.
# Test  total P&L : +858.5920
# Test  final value: 958.5920
# Test  realized PnL: +858.5920
# Test  non-hold steps: 145310
# Episode   10/100  return=  -7.032  avg10=  +0.276  ε=0.817  mem=10000
# Episode   20/100  return=  +5.291  avg10=  +6.365  ε=0.668  mem=20000
# Episode   30/100  return= -38.947  avg10= -15.799  ε=0.545  mem=30000
# Episode   40/100  return=  -1.240  avg10=  +1.676  ε=0.446  mem=40000
# Episode   50/100  return=+179.394  avg10= +39.153  ε=0.364  mem=50000
# Episode   60/100  return=  +2.134  avg10= -13.041  ε=0.298  mem=50000
# Episode   70/100  return=  -2.364  avg10=  +1.377  ε=0.243  mem=50000
# Episode   80/100  return=-141.065  avg10=+670.938  ε=0.199  mem=50000
# Episode   90/100  return=  -1.053  avg10= -13.450  ε=0.162  mem=50000
# Episode  100/100  return=  +0.567  avg10=+13595.118  ε=0.133  mem=50000
# Training complete.
# Test  total P&L : -274.3826
# Test  final value: -174.3826
# Test  realized PnL: -274.3826
# Test  non-hold steps: 51200
# Episode   10/100  return=  -7.823  avg10=+115.409  ε=0.817  mem=10000
# Episode   20/100  return=  -5.661  avg10=  -0.325  ε=0.668  mem=20000
# Episode   30/100  return=  -3.799  avg10=+161.349  ε=0.545  mem=30000
# Episode   40/100  return= -24.517  avg10=  +0.817  ε=0.446  mem=40000
# Episode   50/100  return= +10.719  avg10=  -4.218  ε=0.364  mem=50000
# Episode   60/100  return=  -7.213  avg10=-699.718  ε=0.298  mem=50000
# Episode   70/100  return=  -0.176  avg10=  -4.611  ε=0.243  mem=50000
# Episode   80/100  return=  -1.407  avg10=+1181.303  ε=0.199  mem=50000
# Episode   90/100  return=  -1.958  avg10=  -9.921  ε=0.162  mem=50000
# Episode  100/100  return= +12.407  avg10= -63.259  ε=0.133  mem=50000
# Training complete.
# Test  total P&L : -274.3826
# Test  final value: -174.3826
# Test  realized PnL: -274.3826
# Test  non-hold steps: 51200
# Episode   10/100  return=  +9.267  avg10=+11337.959  ε=0.817  mem=10000
# Episode   20/100  return= -83.396  avg10= -13.480  ε=0.668  mem=20000
# Episode   30/100  return=  -4.463  avg10=+103.731  ε=0.545  mem=30000
# Episode   40/100  return=  -8.482  avg10= -11.971  ε=0.446  mem=40000
# Episode   50/100  return=  -4.093  avg10=  -3.803  ε=0.364  mem=50000
# Episode   60/100  return=-104.151  avg10= -12.040  ε=0.298  mem=50000
# Episode   70/100  return=  +6.355  avg10=  -2.465  ε=0.243  mem=50000
# Episode   80/100  return=  -9.661  avg10= -32.550  ε=0.199  mem=50000
# Episode   90/100  return=  -3.414  avg10=  +7.894  ε=0.162  mem=50000
# Episode  100/100  return=  -2.473  avg10=  -7.084  ε=0.133  mem=50000
# Training complete.
# Test  total P&L : +0.0000
# Test  final value: 100.0000
# Test  realized PnL: +0.0000
# Test  non-hold steps: 0
# Episode   10/100  return= +91.071  avg10=+187.419  ε=0.817  mem=10000
# Episode   20/100  return= +21.205  avg10= +14.286  ε=0.668  mem=20000
# Episode   30/100  return= -13.887  avg10= +22.783  ε=0.545  mem=30000
# Episode   40/100  return= -57.999  avg10=  -2.227  ε=0.446  mem=40000
# Episode   50/100  return=-104.461  avg10=-8625773.931  ε=0.364  mem=50000
# Episode   60/100  return=  +7.247  avg10=  -0.011  ε=0.298  mem=50000
# Episode   70/100  return=  +5.659  avg10=  +6.532  ε=0.243  mem=50000
# Episode   80/100  return=  -3.292  avg10=+394.987  ε=0.199  mem=50000
# Episode   90/100  return=  -7.487  avg10=  +8.805  ε=0.162  mem=50000
# Episode  100/100  return= +12.057  avg10=  +0.753  ε=0.133  mem=50000
# Training complete.
# Test  total P&L : +0.0000
# Test  final value: 100.0000
# Test  realized PnL: +0.0000
# Test  non-hold steps: 0
# Episode   10/100  return=  -1.110  avg10= +31.744  ε=0.817  mem=10000
# Episode   20/100  return= -26.271  avg10=  -1.871  ε=0.668  mem=20000
# Episode   30/100  return=  -6.626  avg10=-518419.812  ε=0.545  mem=30000
# Episode   40/100  return=  -0.376  avg10= -15.448  ε=0.446  mem=40000
# Episode   50/100  return= +18.871  avg10=  -1.734  ε=0.364  mem=50000
# Episode   60/100  return=  +1.213  avg10=  +0.495  ε=0.298  mem=50000
# Episode   70/100  return= -10.278  avg10=  -0.112  ε=0.243  mem=50000
# Episode   80/100  return=  -5.317  avg10= -10.104  ε=0.199  mem=50000
# Episode   90/100  return=  +2.419  avg10= +12.093  ε=0.162  mem=50000
# Episode  100/100  return=  +9.645  avg10=  +0.079  ε=0.133  mem=50000
# Training complete.
# Test  total P&L : -274.3826
# Test  final value: -174.3826
# Test  realized PnL: -274.3826
# Test  non-hold steps: 51200
# Episode   10/100  return=  +0.000  avg10=  -0.000  ε=0.817  mem=10000
# Episode   20/100  return=  +0.000  avg10=  +0.000  ε=0.668  mem=20000
# Episode   30/100  return=  +0.000  avg10=  +0.000  ε=0.545  mem=30000
# Episode   40/100  return=  +0.000  avg10=  +0.000  ε=0.446  mem=40000
# Episode   50/100  return=  +0.000  avg10=  -0.000  ε=0.364  mem=50000
# Episode   60/100  return=  +0.000  avg10=  -0.000  ε=0.298  mem=50000
# Episode   70/100  return=  -0.000  avg10=  -0.000  ε=0.243  mem=50000
# Episode   80/100  return=  +0.000  avg10=  +0.000  ε=0.199  mem=50000
# Episode   90/100  return=  +0.000  avg10=  +0.000  ε=0.162  mem=50000
# Episode  100/100  return=  +0.000  avg10=  -0.000  ε=0.133  mem=50000
# Training complete.
# Test  total P&L : +0.0000
# Test  final value: 100.0000
# Test  realized PnL: -0.0000
# Test  non-hold steps: 48000
# Episode   10/100  return=  +0.000  avg10=  +0.000  ε=0.817  mem=10000
# Episode   20/100  return=  +0.000  avg10=  +0.000  ε=0.668  mem=20000
# Episode   30/100  return=  +0.000  avg10=  -0.000  ε=0.545  mem=30000
# Episode   40/100  return=  +0.000  avg10=  +0.000  ε=0.446  mem=40000
# Episode   50/100  return=  +0.000  avg10=  +0.000  ε=0.364  mem=50000
# Episode   60/100  return=  +0.000  avg10=  +0.000  ε=0.298  mem=50000
# Episode   70/100  return=  +0.000  avg10=  +0.000  ε=0.243  mem=50000
# Episode   80/100  return=  +0.000  avg10=  +0.000  ε=0.199  mem=50000
# Episode   90/100  return=  +0.000  avg10=  +0.000  ε=0.162  mem=50000
# Episode  100/100  return=  +0.000  avg10=  -0.000  ε=0.133  mem=50000
# Training complete.
# Test  total P&L : +0.0000
# Test  final value: 100.0000
# Test  realized PnL: +0.0000
# Test  non-hold steps: 48000
# Episode   10/100  return=  +0.000  avg10=  +0.000  ε=0.817  mem=10000
# Episode   20/100  return=  +0.000  avg10=  +0.000  ε=0.668  mem=20000
# Episode   30/100  return=  +0.000  avg10=  -0.000  ε=0.545  mem=30000
# Episode   40/100  return=  +0.000  avg10=  +0.000  ε=0.446  mem=40000
# Episode   50/100  return=  +0.000  avg10=  +0.000  ε=0.364  mem=50000
# Episode   60/100  return=  +0.000  avg10=  +0.000  ε=0.298  mem=50000
# Episode   70/100  return=  +0.000  avg10=  +0.000  ε=0.243  mem=50000
# Episode   80/100  return=  +0.000  avg10=  +0.000  ε=0.199  mem=50000
# Episode   90/100  return=  +0.000  avg10=  -0.000  ε=0.162  mem=50000
# Episode  100/100  return=  +0.000  avg10=  +0.000  ε=0.133  mem=50000
# Training complete.
# Test  total P&L : +0.0000
# Test  final value: 100.0000
# Test  realized PnL: +0.0000
# Test  non-hold steps: 0
# Episode   10/100  return=  +0.000  avg10=  +0.000  ε=0.817  mem=10000
# Episode   20/100  return=  +0.000  avg10=  -0.000  ε=0.668  mem=20000
# Episode   30/100  return=  +0.000  avg10=  -0.000  ε=0.545  mem=30000
# Episode   40/100  return=  +0.000  avg10=  -0.000  ε=0.446  mem=40000
# Episode   50/100  return=  +0.000  avg10=  +0.000  ε=0.364  mem=50000
# Episode   60/100  return=  +0.000  avg10=  +0.000  ε=0.298  mem=50000
# Episode   70/100  return=  +0.000  avg10=  -0.000  ε=0.243  mem=50000
# Episode   80/100  return=  +0.000  avg10=  +0.000  ε=0.199  mem=50000
# Episode   90/100  return=  +0.000  avg10=  +0.000  ε=0.162  mem=50000
# Episode  100/100  return=  +0.000  avg10=  +0.000  ε=0.133  mem=50000
# Training complete.
# Test  total P&L : +0.0000
# Test  final value: 100.0000
# Test  realized PnL: +0.0000
# Test  non-hold steps: 48000
# Episode   10/100  return=  +0.000  avg10=  +0.000  ε=0.817  mem=10000
# Episode   20/100  return=  +0.000  avg10=  +0.000  ε=0.668  mem=20000
# Episode   30/100  return=  +0.000  avg10=  +0.000  ε=0.545  mem=30000
# Episode   40/100  return=  +0.000  avg10=  -0.000  ε=0.446  mem=40000
# Episode   50/100  return=  +0.000  avg10=  -0.000  ε=0.364  mem=50000
# Episode   60/100  return=  +0.000  avg10=  -0.000  ε=0.298  mem=50000
# Episode   70/100  return=  -0.000  avg10=  -0.000  ε=0.243  mem=50000
# Episode   80/100  return=  -0.000  avg10=  -0.000  ε=0.199  mem=50000
# Episode   90/100  return=  +0.000  avg10=  +0.000  ε=0.162  mem=50000
# Episode  100/100  return=  +0.000  avg10=  +0.000  ε=0.133  mem=50000
# Training complete.
# Test  total P&L : +0.0000
# Test  final value: 100.0000
# Test  realized PnL: -0.0000
# Test  non-hold steps: 48000

# %%
for j in range(len(agents)):
    for i in range(len(df_as)):
        print("Agent number " + str(j) + " on data number " + str(i) + " achieved mean " + str(np.mean(arrs[j][i])) + " and sd " + str(np.std(arrs[j][i])))
# Out:
# Agent number 0 on data number 0 achieved mean 1467.3848051206508 and sd 913.3015831948071
# Agent number 0 on data number 1 achieved mean 82.79872853324905 and sd 115.83678193402908
# Agent number 0 on data number 2 achieved mean 0.0 and sd 0.0
# Agent number 1 on data number 0 achieved mean 1553.8739289950906 and sd 904.5945400630401
# Agent number 1 on data number 1 achieved mean 278.3784786197654 and sd 179.91936744410023
# Agent number 1 on data number 2 achieved mean 0.0 and sd 0.0
# Agent number 2 on data number 0 achieved mean 906.5351835964404 and sd 841.5975938925828
# Agent number 2 on data number 1 achieved mean -164.62958209074085 and sd 134.4194908966503
# Agent number 2 on data number 2 achieved mean 0.0 and sd 0.0
